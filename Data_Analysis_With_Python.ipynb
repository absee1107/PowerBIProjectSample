# %% [markdown]
# <a href="https://colab.research.google.com/github/absee1107/PowerBIProjectSample/blob/main/Data_Analysis_With_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/BaseBall.csv')

# %%
df.head()
# Out:
#        Lname   Fname Team_at_the_End_of  Times_at  Hits_in  Home_Runs  \
# 0   Allanson    Andy          Cleveland       293       66          1
# 1      Ashby    Alan            Houston       315       81          7
# 2      Davis    Alan            Seattle       479      130         18
# 3     Dawson   Andre           Montreal       496      141         20
# 4  Galarraga  Andres           Montreal       321       87         10
#
#    Runs_in  RBIs_in  Walks_in  Years_in  ...  Career_Walks  League_at_the  \
# 0       30       29        14         1  ...            14       American
# 1       24       38        39        14  ...           375       National
# 2       66       72        76         3  ...           263       American
# 3       65       78        37        11  ...           354       National
# 4       39       42        30         2  ...            33       National
#
#    Division  Position  Put_Outs  Assists Errors 1987_Salary League  Log_Salary
# 0      East         C       446       33     20      535.92     AE     5.92000
# 1      West         C       632       43     10      475.00     NW     6.16331
# 2      West        1B       880       82     14      480.00     AW     6.17379
# 3      East        RF       200       11      3      500.00     NE     6.21461
# 4      East        1B       805       40      4       91.50     NE     4.51634
#
# [5 rows x 25 columns]

# %%
df.corr()
# Out:
# <ipython-input-7-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               Times_at   Hits_in  Home_Runs   Runs_in   RBIs_in  Walks_in  \
# Times_at      1.000000  0.964471   0.573066  0.902602  0.802811  0.635778
# Hits_in       0.964471  1.000000   0.541654  0.911666  0.793115  0.606202
# Home_Runs     0.573066  0.541654   1.000000  0.639649  0.853942  0.468349
# Runs_in       0.902602  0.911666   0.639649  1.000000  0.780532  0.712881
# RBIs_in       0.802811  0.793115   0.853942  0.780532  1.000000  0.590700
# Walks_in      0.635778  0.606202   0.468349  0.712881  0.590700  1.000000
# Years_in     -0.008483 -0.008032   0.097684 -0.042669  0.112911  0.108703
# Career_Times  0.185556  0.179435   0.202872  0.141532  0.262756  0.247475
# Career_Hits   0.205682  0.211114   0.201786  0.161928  0.277398  0.251699
# Career_Home   0.205770  0.173975   0.492701  0.206490  0.435516  0.324783
# Career_Runs   0.223149  0.221195   0.254135  0.216604  0.300969  0.318835
# Career_RBIs   0.203166  0.192608   0.343686  0.171277  0.374748  0.289553
# Career_Walks  0.123369  0.112289   0.234777  0.155111  0.236477  0.415012
# Put_Outs      0.343953  0.327432   0.273194  0.285014  0.348609  0.301211
# Assists       0.357579  0.321307  -0.111336  0.214381  0.098868  0.140359
# Errors        0.357888  0.310549   0.023938  0.232651  0.182449  0.112599
# 1987_Salary   0.414299  0.451042   0.365613  0.433061  0.471174  0.464775
# Log_Salary    0.415367  0.443871   0.340911  0.419233  0.442946  0.432804
#
#               Years_in  Career_Times  Career_Hits  Career_Home  Career_Runs  \
# Times_at     -0.008483      0.185556     0.205682     0.205770     0.223149
# Hits_in      -0.008032      0.179435     0.211114     0.173975     0.221195
# Home_Runs     0.097684      0.202872     0.201786     0.492701     0.254135
# Runs_in      -0.042669      0.141532     0.161928     0.206490     0.216604
# RBIs_in       0.112911      0.262756     0.277398     0.435516     0.300969
# Walks_in      0.108703      0.247475     0.251699     0.324783     0.318835
# Years_in      1.000000      0.920662     0.903518     0.721487     0.879472
# Career_Times  0.920662      1.000000     0.994892     0.792221     0.980695
# Career_Hits   0.903518      0.994892     1.000000     0.775726     0.982083
# Career_Home   0.721487      0.792221     0.775726     1.000000     0.820930
# Career_Runs   0.879472      0.980695     0.982083     0.820930     1.000000
# Career_RBIs   0.868221      0.947415     0.942544     0.927985     0.943141
# Career_Walks  0.832990      0.900345     0.884523     0.806193     0.926772
# Put_Outs     -0.009952      0.061036     0.074612     0.089652     0.054204
# Assists      -0.097302     -0.013053    -0.016525    -0.160321    -0.033567
# Errors       -0.186119     -0.088050    -0.083252    -0.158375    -0.106250
# 1987_Salary   0.385688      0.507984     0.530213     0.501658     0.551009
# Log_Salary    0.491054      0.566759     0.578199     0.471370     0.581719
#
#               Career_RBIs  Career_Walks  Put_Outs   Assists    Errors  \
# Times_at         0.203166      0.123369  0.343953  0.357579  0.357888
# Hits_in          0.192608      0.112289  0.327432  0.321307  0.310549
# Home_Runs        0.343686      0.234777  0.273194 -0.111336  0.023938
# Runs_in          0.171277      0.155111  0.285014  0.214381  0.232651
# RBIs_in          0.374748      0.236477  0.348609  0.098868  0.182449
# Walks_in         0.289553      0.415012  0.301211  0.140359  0.112599
# Years_in         0.868221      0.832990 -0.009952 -0.097302 -0.186119
# Career_Times     0.947415      0.900345  0.061036 -0.013053 -0.088050
# Career_Hits      0.942544      0.884523  0.074612 -0.016525 -0.083252
# Career_Home      0.927985      0.806193  0.089652 -0.160321 -0.158375
# Career_Runs      0.943141      0.926772  0.054204 -0.033567 -0.106250
# Career_RBIs      1.000000      0.885003  0.100882 -0.091255 -0.123244
# Career_Walks     0.885003      1.000000  0.045732 -0.045502 -0.140267
# Put_Outs         0.100882      0.045732  1.000000 -0.025204  0.109738
# Assists         -0.091255     -0.045502 -0.025204  1.000000  0.706346
# Errors          -0.123244     -0.140267  0.109738  0.706346  1.000000
# 1987_Salary      0.541862      0.488977  0.270767  0.024363 -0.005061
# Log_Salary       0.550983      0.511934  0.202328  0.048495 -0.018822
#
#               1987_Salary  Log_Salary
# Times_at         0.414299    0.415367
# Hits_in          0.451042    0.443871
# Home_Runs        0.365613    0.340911
# Runs_in          0.433061    0.419233
# RBIs_in          0.471174    0.442946
# Walks_in         0.464775    0.432804
# Years_in         0.385688    0.491054
# Career_Times     0.507984    0.566759
# Career_Hits      0.530213    0.578199
# Career_Home      0.501658    0.471370
# Career_Runs      0.551009    0.581719
# Career_RBIs      0.541862    0.550983
# Career_Walks     0.488977    0.511934
# Put_Outs         0.270767    0.202328
# Assists          0.024363    0.048495
# Errors          -0.005061   -0.018822
# 1987_Salary      1.000000    0.895432
# Log_Salary       0.895432    1.000000

# %%
df.isnull().sum()
# Out:
# Lname                 0
# Fname                 0
# Team_at_the_End_of    0
# Times_at              0
# Hits_in               0
# Home_Runs             0
# Runs_in               0
# RBIs_in               0
# Walks_in              0
# Years_in              0
# Career_Times          0
# Career_Hits           0
# Career_Home           0
# Career_Runs           0
# Career_RBIs           0
# Career_Walks          0
# League_at_the         0
# Division              0
# Position              0
# Put_Outs              0
# Assists               0
# Errors                0
# 1987_Salary           0
# League                0
# Log_Salary            0
# dtype: int64

# %%
df.describe()
# Out:
#          Times_at     Hits_in   Home_Runs     Runs_in     RBIs_in    Walks_in  \
# count  322.000000  322.000000  322.000000  322.000000  322.000000  322.000000
# mean   390.074534  103.397516   11.102484   52.217391   49.372671   39.857143
# std    143.595835   44.179509    8.698770   25.057366   25.501162   21.095941
# min    127.000000   31.000000    0.000000   12.000000    8.000000    3.000000
# 25%    272.000000   68.000000    4.000000   32.000000   29.000000   22.000000
# 50%    390.500000   98.500000    8.500000   48.000000   45.000000   35.500000
# 75%    512.750000  137.750000   16.000000   70.000000   65.000000   54.000000
# max    687.000000  238.000000   40.000000  130.000000  121.000000  105.000000
#
#          Years_in  Career_Times  Career_Hits  Career_Home  Career_Runs  \
# count  322.000000    322.000000   322.000000   322.000000   322.000000
# mean     7.680124   2763.077640   747.686335    74.090062   374.285714
# std      4.969707   2328.479167   654.787619    90.065127   336.425038
# min      1.000000    166.000000    34.000000     0.000000    18.000000
# 25%      4.000000    911.250000   227.250000    16.000000   106.250000
# 50%      6.000000   2065.000000   552.000000    40.000000   266.000000
# 75%     11.000000   4068.500000  1095.750000    95.500000   556.500000
# max     24.000000  14053.000000  4256.000000   548.000000  2165.000000
#
#        Career_RBIs  Career_Walks     Put_Outs     Assists      Errors  \
# count   322.000000    322.000000   322.000000  322.000000  322.000000
# mean    347.614907    273.394410   288.993789  106.916149    8.040373
# std     338.790345    273.625372   280.656673  136.852454    6.368359
# min       9.000000      8.000000     0.000000    0.000000    0.000000
# 25%      98.250000     76.000000   109.250000    7.000000    3.000000
# 50%     250.000000    178.500000   212.000000   39.500000    6.000000
# 75%     461.000000    370.750000   325.000000  166.000000   11.000000
# max    1659.000000   1566.000000  1378.000000  492.000000   32.000000
#
#        1987_Salary  Log_Salary
# count   322.000000  322.000000
# mean    535.924783    5.925898
# std     407.557436    0.803334
# min      67.500000    4.212130
# 25%     226.250000    5.421595
# 50%     535.920000    5.920000
# 75%     700.000000    6.551080
# max    2460.000000    7.807920

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Lname               322 non-null    object
#  1   Fname               322 non-null    object
#  2   Team_at_the_End_of  322 non-null    object
#  3   Times_at            322 non-null    int64
#  4   Hits_in             322 non-null    int64
#  5   Home_Runs           322 non-null    int64
#  6   Runs_in             322 non-null    int64
#  7   RBIs_in             322 non-null    int64
#  8   Walks_in            322 non-null    int64
#  9   Years_in            322 non-null    int64
#  10  Career_Times        322 non-null    int64
#  11  Career_Hits         322 non-null    int64
#  12  Career_Home         322 non-null    int64
#  13  Career_Runs         322 non-null    int64
#  14  Career_RBIs         322 non-null    int64
#  15  Career_Walks        322 non-null    int64
#  16  League_at_the       322 non-null    object
#  17  Division            322 non-null    object
#  18  Position            322 non-null    object
#  19  Put_Outs            322 non-null    int64
#  20  Assists             322 non-null    int64
#  21  Errors              322 non-null    int64
#  22  1987_Salary         322 non-null    float64
#  23  League              322 non-null    object
#  24  Log_Salary          322 non-null    float64
# dtypes: float64(2), int64(16), object(7)
# memory usage: 63.0+ KB

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-8-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-1a6fe1782b2f> in <cell line: 1>()
# ----> 1 sns.pairplot(df)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2172         grid.add_legend()
#    2173
# -> 2174     grid.tight_layout()
#    2175
#    2176     return grid
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in tight_layout(self, *args, **kwargs)
#     116         if self._tight_layout_pad is not None:
#     117             kwargs.setdefault("pad", self._tight_layout_pad)
# --> 118         self._figure.tight_layout(*args, **kwargs)
#     119         return self
#     120
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in tight_layout(self, pad, h_pad, w_pad, rect)
#    3507             previous_engine = self.get_layout_engine()
#    3508             self.set_layout_engine(engine)
# -> 3509             engine.execute(self)
#    3510             if not isinstance(previous_engine, TightLayoutEngine) \
#    3511                     and previous_engine is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/layout_engine.py in execute(self, fig)
#     176         renderer = fig._get_renderer()
#     177         with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 178             kwargs = get_tight_layout_figure(
#     179                 fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     180                 pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     264             slice(ss.colspan.start * div_col, ss.colspan.stop * div_col)))
#     265
# --> 266     kwargs = _auto_adjust_subplotpars(fig, renderer,
#     267                                       shape=(max_nrows, max_ncols),
#     268                                       span_pairs=span_pairs,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_tight_layout.py in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80         for ax in subplots:
#      81             if ax.get_visible():
# ---> 82                 bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      83
#      84         tight_bbox_raw = Bbox.union(bb)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1413     """
#    1414     try:
# -> 1415         return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1416     except TypeError:
#    1417         return obj.get_tightbbox(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4386                 if ba:
#    4387                     bb.append(ba)
# -> 4388         self._update_title_position(renderer)
#    4389         axbbox = self.get_window_extent(renderer)
#    4390         bb.append(axbbox)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2961                 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2962                         or ax.xaxis.get_label_position() == 'top'):
# -> 2963                     bb = ax.xaxis.get_tightbbox(renderer)
#    2964                 if bb is None:
#    2965                     if 'outline' in ax.spines:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1323         ticks_to_draw = self._update_ticks()
#    1324
# -> 1325         self._update_label_position(renderer)
#    1326
#    1327         # go back to just this axis's tick labels
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2302         # get bounding boxes for this axis and any siblings
#    2303         # that have been set by `fig.align_xlabels()`
# -> 2304         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2305
#    2306         x, y = self.label.get_position()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    2097         for ax in grouper.get_siblings(self.axes):
#    2098             axis = getattr(ax, f"{axis_name}axis")
# -> 2099             ticks_to_draw = axis._update_ticks()
#    2100             tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2101             bboxes.extend(tlb)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _update_ticks(self)
#    1263         major_labels = self.major.formatter.format_ticks(major_locs)
#    1264         major_ticks = self.get_major_ticks(len(major_locs))
# -> 1265         self.major.formatter.set_locs(major_locs)
#    1266         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#    1267             tick.update_position(loc)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/ticker.py in set_locs(self, locs)
#     699         if len(self.locs) > 0:
#     700             if self._useOffset:
# --> 701                 self._compute_offset()
#     702             self._set_order_of_magnitude()
#     703             self._set_format()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/ticker.py in _compute_offset(self)
#     706         locs = self.locs
#     707         # Restrict to visible ticks.
# --> 708         vmin, vmax = sorted(self.axis.get_view_interval())
#     709         locs = np.asarray(locs)
#     710         locs = locs[(vmin <= locs) & (locs <= vmax)]
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in getter(self)
#    2204     def getter(self):
#    2205         # docstring inherited.
# -> 2206         return getattr(getattr(self.axes, lim_name), attr_name)
#    2207
#    2208     def setter(self, vmin, vmax, ignore=False):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in viewLim(self)
#     855     @property
#     856     def viewLim(self):
# --> 857         self._unstale_viewLim()
#     858         return self._viewLim
#     859
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _unstale_viewLim(self)
#     842         # We should arrange to store this information once per share-group
#     843         # instead of on every axis.
# --> 844         need_scale = {
#     845             name: any(ax._stale_viewlims[name]
#     846                       for ax in self._shared_axes[name].get_siblings(self))
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in <dictcomp>(.0)
#     844         need_scale = {
#     845             name: any(ax._stale_viewlims[name]
# --> 846                       for ax in self._shared_axes[name].get_siblings(self))
#     847             for name in self._axis_names}
#     848         if any(need_scale.values()):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py in get_siblings(self, a)
#     880     def get_siblings(self, a):
#     881         """Return all of the items joined with *a*, including itself."""
# --> 882         self.clean()
#     883         siblings = self._mapping.get(weakref.ref(a), [weakref.ref(a)])
#     884         return [x() for x in siblings]
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py in clean(self)
#     832         """Clean dead weak references from the dictionary."""
#     833         mapping = self._mapping
# --> 834         to_drop = [key for key in mapping if key() is None]
#     835         for key in to_drop:
#     836             val = mapping.pop(key)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py in <listcomp>(.0)
#     832         """Clean dead weak references from the dictionary."""
#     833         mapping = self._mapping
# --> 834         to_drop = [key for key in mapping if key() is None]
#     835         for key in to_drop:
#     836             val = mapping.pop(key)
#
# KeyboardInterrupt:
# Error in callback <function _draw_all_if_interactive at 0x7f9280cc9d80> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#     121
#     122
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for manager in cls.get_all_fig_managers():
#     131             if force or manager.canvas.figure.stale:
# --> 132                 manager.canvas.draw_idle()
#     133
#     134
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2080         if not self._is_idle_drawing:
#    2081             with self._idle_draw_cntx():
# -> 2082                 self.draw(*args, **kwargs)
#    2083
#    2084     @property
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     398              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399               else nullcontext()):
# --> 400             self.figure.draw(self.renderer)
#     401             # A GUI class may be need to update a window using this draw, so
#     402             # don't forget to call the superclass.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3138
#    3139             self.patch.draw(renderer)
# -> 3140             mimage._draw_list_compositing_images(
#    3141                 renderer, self, artists, self.suppressComposite)
#    3142
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3026                 artists.remove(spine)
#    3027
# -> 3028         self._update_title_position(renderer)
#    3029
#    3030         if not self.axison:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2961                 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2962                         or ax.xaxis.get_label_position() == 'top'):
# -> 2963                     bb = ax.xaxis.get_tightbbox(renderer)
#    2964                 if bb is None:
#    2965                     if 'outline' in ax.spines:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1323         ticks_to_draw = self._update_ticks()
#    1324
# -> 1325         self._update_label_position(renderer)
#    1326
#    1327         # go back to just this axis's tick labels
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2308             try:
#    2309                 spine = self.axes.spines['bottom']
# -> 2310                 spinebbox = spine.get_window_extent()
#    2311             except KeyError:
#    2312                 # use Axes if spine doesn't exist
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/spines.py in get_window_extent(self, renderer)
#     156             return bb
#     157         bboxes = [bb]
# --> 158         drawn_ticks = self.axis._update_ticks()
#     159
#     160         major_tick = next(iter({*drawn_ticks} & {*self.axis.majorTicks}), None)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _update_ticks(self)
#    1263         major_labels = self.major.formatter.format_ticks(major_locs)
#    1264         major_ticks = self.get_major_ticks(len(major_locs))
# -> 1265         self.major.formatter.set_locs(major_locs)
#    1266         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#    1267             tick.update_position(loc)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/ticker.py in set_locs(self, locs)
#     699         if len(self.locs) > 0:
#     700             if self._useOffset:
# --> 701                 self._compute_offset()
#     702             self._set_order_of_magnitude()
#     703             self._set_format()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/ticker.py in _compute_offset(self)
#     706         locs = self.locs
#     707         # Restrict to visible ticks.
# --> 708         vmin, vmax = sorted(self.axis.get_view_interval())
#     709         locs = np.asarray(locs)
#     710         locs = locs[(vmin <= locs) & (locs <= vmax)]
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in getter(self)
#    2204     def getter(self):
#    2205         # docstring inherited.
# -> 2206         return getattr(getattr(self.axes, lim_name), attr_name)
#    2207
#    2208     def setter(self, vmin, vmax, ignore=False):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in viewLim(self)
#     855     @property
#     856     def viewLim(self):
# --> 857         self._unstale_viewLim()
#     858         return self._viewLim
#     859
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _unstale_viewLim(self)
#     842         # We should arrange to store this information once per share-group
#     843         # instead of on every axis.
# --> 844         need_scale = {
#     845             name: any(ax._stale_viewlims[name]
#     846                       for ax in self._shared_axes[name].get_siblings(self))
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in <dictcomp>(.0)
#     844         need_scale = {
#     845             name: any(ax._stale_viewlims[name]
# --> 846                       for ax in self._shared_axes[name].get_siblings(self))
#     847             for name in self._axis_names}
#     848         if any(need_scale.values()):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py in get_siblings(self, a)
#     880     def get_siblings(self, a):
#     881         """Return all of the items joined with *a*, including itself."""
# --> 882         self.clean()
#     883         siblings = self._mapping.get(weakref.ref(a), [weakref.ref(a)])
#     884         return [x() for x in siblings]
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py in clean(self)
#     832         """Clean dead weak references from the dictionary."""
#     833         mapping = self._mapping
# --> 834         to_drop = [key for key in mapping if key() is None]
#     835         for key in to_drop:
#     836             val = mapping.pop(key)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py in <listcomp>(.0)
#     832         """Clean dead weak references from the dictionary."""
#     833         mapping = self._mapping
# --> 834         to_drop = [key for key in mapping if key() is None]
#     835         for key in to_drop:
#     836             val = mapping.pop(key)
#
# KeyboardInterrupt:
